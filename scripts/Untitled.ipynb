# %%
import pandas as pd

# %%
summary_df_sp500 = pd.read_pickle("../data/processed/sp500_summary.pkl")
summary_df_ftse100 = pd.read_pickle("../data/processed/ftse100_summary.pkl")

df_clusters_sp500 = pd.read_pickle("../data/processed/df_clusters_sp500.pkl")
df_clusters_ftse100 = pd.read_pickle("../data/processed/df_clusters_ftse100.pkl")

# %%
df_clusters_ftse100
# Out:
#         Cluster    UMAP-1     UMAP-2  Avg Correlation  Volatility  \
# Ticker
# AZN_L         2  3.754041  13.896700           0.2888      0.0158
# BP_L          0  6.606061  13.672378           0.4768      0.0231
# HSBA_L        3  5.024402  13.372350           0.4389      0.0181
# LLOY_L        1  5.615571  14.235603           0.4340      0.0214
# NG_L          2  4.326882  14.540577           0.3374      0.0145
# RIO_L         3  4.506383  12.582310           0.3926      0.0198
# SHEL_L        0  6.173661  12.966098           0.4729      0.0220
# ULVR_L        2  3.604399  12.989037           0.3095      0.0129
# VOD_L         1  6.282814  14.777199           0.4081      0.0180
#
#         Max Drawdown  Skewness  Kurtosis  Sharpe Ratio
# Ticker
# AZN_L        -0.2868   -0.3794    4.2318        0.2496
# BP_L         -0.6670   -0.2967   13.1480       -0.1084
# HSBA_L       -0.5512   -0.2237    4.3711        0.1943
# LLOY_L       -0.6590   -0.3453    5.3922       -0.0878
# ...

# %%
len(df_clusters_ftse100["Cluster"].unique())
# Out:
# 4
